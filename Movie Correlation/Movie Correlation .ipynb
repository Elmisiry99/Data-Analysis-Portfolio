# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
import os

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) 

#Read in the data 
df = pd.read_csv(os.path.join(os.getcwd(), 'movies.csv'))

# %%
# Reordering the columns of the dataframe by ascending order

cols = df.columns.tolist()
cols.sort()
df = df[cols]

# %%
# Taking a look at the data
df.head()
# Out:
#        budget             company         country         director      genre  \
# 0  19000000.0        Warner Bros.  United Kingdom  Stanley Kubrick      Drama
# 1   4500000.0   Columbia Pictures   United States   Randal Kleiser  Adventure
# 2  18000000.0           Lucasfilm   United States   Irvin Kershner     Action
# 3   3500000.0  Paramount Pictures   United States     Jim Abrahams     Comedy
# 4   6000000.0      Orion Pictures   United States     Harold Ramis     Comedy
#
#          gross                                            name rating  \
# 0   46998772.0                                     The Shining      R
# 1   58853106.0                                 The Blue Lagoon      R
# 2  538375067.0  Star Wars: Episode V - The Empire Strikes Back     PG
# 3   83453539.0                                       Airplane!     PG
# 4   39846344.0                                      Caddyshack      R
#
#                         released  runtime  score            star      votes  \
# 0  June 13, 1980 (United States)    146.0    8.4  Jack Nicholson   927000.0
# 1   July 2, 1980 (United States)    104.0    5.8  Brooke Shields    65000.0
# 2  June 20, 1980 (United States)    124.0    8.7     Mark Hamill  1200000.0
# 3   July 2, 1980 (United States)     88.0    7.7     Robert Hays   221000.0
# 4  July 25, 1980 (United States)     98.0    7.3     Chevy Chase   108000.0
#
#                     writer  year
# 0             Stephen King  1980
# 1  Henry De Vere Stacpoole  1980
# 2           Leigh Brackett  1980
# 3             Jim Abrahams  1980
# 4       Brian Doyle-Murray  1980

# %%
#Checking if there is missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# budget - 0.2831246739697444%
# company - 0.002217005738132499%
# country - 0.0003912363067292645%
# director - 0.0%
# genre - 0.0%
# gross - 0.02464788732394366%
# name - 0.0%
# rating - 0.010041731872717789%
# released - 0.0002608242044861763%
# runtime - 0.0005216484089723526%
# score - 0.0003912363067292645%
# star - 0.00013041210224308815%
# votes - 0.0003912363067292645%
# writer - 0.0003912363067292645%
# year - 0.0%

# %%
len(df[df.isna().any(axis=1)].index)
# Out:
# 2247

# %%
df = df.dropna()

# %%
# Data types of the column
df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime     float64
# score       float64
# star         object
# votes       float64
# writer       object
# year          int64
# dtype: object

# %%
# change data type of columns 

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# add the correct year column

#df[['0', '1']] = df['released'].str.split(',', expand=True)
df['year_correct'] = df['released'].str.split(',', expand=True)[1].str[1:5]
#df['year_correct'] = df['released'].astype(str).str[:4]

# %%
len(df[df.isna().any(axis=1)].index)
# Out:
# 14

# %%
#viewing rows with nan values
df[df.isna().any(axis=1)]
# Out:
#         budget                            company         country  \
# 312   15000000         Cable and Wireless Finance   United States
# 449     220000               Seventh Avenue Films   United States
# 467      50000        Charles Burnett Productions   United States
# 800    7000000          Metro-Goldwyn-Mayer (MGM)   United States
# 1173  14000000                     Orion Pictures   United States
# 1212   5500000               Cineplex Odeon Films  United Kingdom
# 1404   4000000       Atlantic Entertainment Group  United Kingdom
# 1819  17500000              Twentieth Century Fox   United States
# 2029   6900000  Initial Entertainment Group (IEG)   United States
# 2318   1500000                        Davis-Films          France
# 2319   2000000                            CNCAIMC          Mexico
# 2816    150000           Farabi Cinema Foundation            Iran
# 4187    250000                  Blockbuster Films   United States
# 5833    800000                 ArieScope Pictures   United States
#
#                 director      genre    gross                         name  \
# 312       Fred Zinnemann      Drama   199078         Five Days One Summer
# 449        William Olsen     Comedy   975414                Getting It on
# 467      Charles Burnett      Drama    26177         My Brother's Wedding
# 800        Robert Altman     Comedy    29815              O.C. and Stiggs
# 1173         Peter Yates   Thriller   459824  The House on Carroll Street
# 1212           Tony Bill      Crime   969205                 Five Corners
# 1404         Mike Figgis      Crime  1791328                Stormy Monday
# 1819         Alan Parker      Drama   947306        Come See the Paradise
# 2029         Mike Figgis    Mystery   133645                  Liebestraum
# 2318         Roger Avary      Crime   418961                  Killing Zoe
# 2319  Guillermo del Toro    Fantasy   621392                       Cronos
# 2816        Jafar Panahi      Drama   924940            The White Balloon
# 4187      David Jacobson  Biography   144008                       Dahmer
# 5833          Adam Green     Action   156190                   Hatchet II
#
#          rating                        released  runtime  score  \
# 312          PG                    1982 (Japan)    108.0    6.1
# 449           R     August 1983 (United States)     96.0    3.7
# 467   Not Rated      March 1985 (United States)    115.0    7.2
# 800           R            1985 (United States)    109.0    5.4
# 1173         PG            1987 (United States)    101.0    6.1
# 1212          R       May 1988 (United Kingdom)     90.0    6.2
# 1404          R        May 1988 (United States)     93.0    6.2
# 1819          R    January 1991 (United States)    138.0    6.7
# 2029          R   November 1991 (United States)    112.0    5.9
# 2318          R  September 1994 (United States)     96.0    6.5
# 2319          R        May 1994 (United States)     94.0    6.7
# 2816    Unrated                     1995 (Iran)     85.0    7.7
# 4187          R            2019 (United States)    101.0    5.6
# 5833          R       November 2010 (Australia)     85.0    5.5
#
#                     star    votes                writer  year year_correct
# 312         Sean Connery   1000.0        Michael Austin  1982         None
# 449          Martin Yost    208.0         William Olsen  1983         None
# 467        Everett Silas    826.0       Charles Burnett  1983         None
# 800       Daniel Jenkins   1200.0           Tod Carroll  1985         None
# 1173      Kelly McGillis   2300.0      Walter Bernstein  1987         None
# 1212        Jodie Foster   3100.0  John Patrick Shanley  1987         None
# 1404    Melanie Griffith   3800.0           Mike Figgis  1988         None
# 1819        Dennis Quaid   2600.0           Alan Parker  1990         None
# 2029      Kevin Anderson   1500.0           Mike Figgis  1991         None
# 2318         Eric Stoltz  20000.0           Roger Avary  1993         None
# 2319      Federico Luppi  28000.0    Guillermo del Toro  1993         None
# 2816  Aida Mohammadkhani   6900.0      Abbas Kiarostami  1995         None
# 4187       Jeremy Renner   9700.0           David Birke  2002         None
# 5833     Danielle Harris  13000.0            Adam Green  2010         None

# %%
df = df.dropna()

# %%
df['year_correct'] = df['year_correct'].astype(str).astype('int64')

# %%
#Checking films, whose extracted year doesn't match year column
counter = 0
for i in df.index:
    if df['year'][i] != df['year_correct'][i]:
        #print( df.loc[[i]]) # printing out rows where year and year_correct don't match
        #print (df['year'][i], df['year_correct'][i])
        counter = counter + 1
print("Number of movies with mismatched release year: ", counter)
# Out:
# Number of movies with mismatched release year:  702

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
# Uncomment to display the whole dataframe
#pd.set_option('display.max_rows', None)

# %%
# Delete duplicates

#df['company'].drop_duplicates().sort_values(ascending=False)
df = df.drop_duplicates()

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
df.head()
# Out:
#          budget                company        country       director   genre  \
# 5445  237000000  Twentieth Century Fox  United States  James Cameron  Action
# 7445  356000000         Marvel Studios  United States  Anthony Russo  Action
# 3045  200000000  Twentieth Century Fox  United States  James Cameron   Drama
# 6663  245000000              Lucasfilm  United States    J.J. Abrams  Action
# 7244  321000000         Marvel Studios  United States  Anthony Russo  Action
#
#            gross                                        name rating  \
# 5445  2847246203                                      Avatar  PG-13
# 7445  2797501328                           Avengers: Endgame  PG-13
# 3045  2201647264                                     Titanic  PG-13
# 6663  2069521700  Star Wars: Episode VII - The Force Awakens  PG-13
# 7244  2048359754                      Avengers: Infinity War  PG-13
#
#                                released  runtime  score               star  \
# 5445  December 18, 2009 (United States)    162.0    7.8    Sam Worthington
# 7445     April 26, 2019 (United States)    181.0    8.4  Robert Downey Jr.
# 3045  December 19, 1997 (United States)    194.0    7.8  Leonardo DiCaprio
# 6663  December 18, 2015 (United States)    138.0    7.8       Daisy Ridley
# 7244     April 27, 2018 (United States)    149.0    8.4  Robert Downey Jr.
#
#           votes              writer  year  year_correct
# 5445  1100000.0       James Cameron  2009          2009
# 7445   903000.0  Christopher Markus  2019          2019
# 3045  1100000.0       James Cameron  1997          1997
# 6663   876000.0     Lawrence Kasdan  2015          2015
# 7244   897000.0  Christopher Markus  2018          2018

# %%
# Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Looking at correlation
df.corr(method='pearson') # Methods: Pearson, kendall, spearman
# Out:
#                 budget     gross   runtime     score     votes      year  \
# budget        1.000000  0.740028  0.318353  0.071552  0.439077  0.326740
# gross         0.740028  1.000000  0.275641  0.222504  0.614432  0.273512
# runtime       0.318353  0.275641  1.000000  0.414501  0.352263  0.074849
# score         0.071552  0.222504  0.414501  1.000000  0.474594  0.055681
# votes         0.439077  0.614432  0.352263  0.474594  1.000000  0.204904
# year          0.326740  0.273512  0.074849  0.055681  0.204904  1.000000
# year_correct  0.319669  0.268141  0.075183  0.061443  0.202215  0.998962
#
#               year_correct
# budget            0.319669
# gross             0.268141
# runtime           0.075183
# score             0.061443
# votes             0.202215
# year              0.998962
# year_correct      1.000000

# %%
# High correlation between budget and gross
corr_matrix = df.corr(method='pearson')

sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix for Numeric features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Converting String columns into catergory type
df_numerized = df.copy(deep=True)

for col in df_numerized.columns:
    if(df_numerized[col].dtype =='object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

# %%
df_numerized.head()
# Out:
#          budget  company  country  director  genre       gross  name  rating  \
# 5445  237000000     1376       47       781      0  2847246203   386       5
# 7445  356000000      978       47       105      0  2797501328   388       5
# 3045  200000000     1376       47       781      6  2201647264  4895       5
# 6663  245000000      940       47       765      0  2069521700  3632       5
# 7244  321000000      978       47       105      0  2048359754   389       5
#
#       released  runtime  score  star      votes  writer  year  year_correct
# 5445       521    162.0    7.8  1527  1100000.0    1260  2009          2009
# 7445       132    181.0    8.4  1463   903000.0     510  2019          2019
# 3045       528    194.0    7.8  1067  1100000.0    1260  1997          1997
# 6663       523    138.0    7.8   355   876000.0    1803  2015          2015
# 7244       140    149.0    8.4  1463   897000.0     510  2018          2018

# %%
df.head()
# Out:
#          budget                company        country       director   genre  \
# 5445  237000000  Twentieth Century Fox  United States  James Cameron  Action
# 7445  356000000         Marvel Studios  United States  Anthony Russo  Action
# 3045  200000000  Twentieth Century Fox  United States  James Cameron   Drama
# 6663  245000000              Lucasfilm  United States    J.J. Abrams  Action
# 7244  321000000         Marvel Studios  United States  Anthony Russo  Action
#
#            gross                                        name rating  \
# 5445  2847246203                                      Avatar  PG-13
# 7445  2797501328                           Avengers: Endgame  PG-13
# 3045  2201647264                                     Titanic  PG-13
# 6663  2069521700  Star Wars: Episode VII - The Force Awakens  PG-13
# 7244  2048359754                      Avengers: Infinity War  PG-13
#
#                                released  runtime  score               star  \
# 5445  December 18, 2009 (United States)    162.0    7.8    Sam Worthington
# 7445     April 26, 2019 (United States)    181.0    8.4  Robert Downey Jr.
# 3045  December 19, 1997 (United States)    194.0    7.8  Leonardo DiCaprio
# 6663  December 18, 2015 (United States)    138.0    7.8       Daisy Ridley
# 7244     April 27, 2018 (United States)    149.0    8.4  Robert Downey Jr.
#
#           votes              writer  year  year_correct
# 5445  1100000.0       James Cameron  2009          2009
# 7445   903000.0  Christopher Markus  2019          2019
# 3045  1100000.0       James Cameron  1997          1997
# 6663   876000.0     Lawrence Kasdan  2015          2015
# 7244   897000.0  Christopher Markus  2018          2018

# %%
# High correlation between budget and gross
corr_matrix_numerized = df_numerized.corr(method='pearson')

sns.heatmap(corr_matrix_numerized, annot=True)
plt.title('Correlation Matrix for Numeric features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
print(corr_matrix)
# Out:
#                 budget     gross   runtime     score     votes      year  \
# budget        1.000000  0.740028  0.318353  0.071552  0.439077  0.326740
# gross         0.740028  1.000000  0.275641  0.222504  0.614432  0.273512
# runtime       0.318353  0.275641  1.000000  0.414501  0.352263  0.074849
# score         0.071552  0.222504  0.414501  1.000000  0.474594  0.055681
# votes         0.439077  0.614432  0.352263  0.474594  1.000000  0.204904
# year          0.326740  0.273512  0.074849  0.055681  0.204904  1.000000
# year_correct  0.319669  0.268141  0.075183  0.061443  0.202215  0.998962
#
#               year_correct
# budget            0.319669
# gross             0.268141
# runtime           0.075183
# score             0.061443
# votes             0.202215
# year              0.998962
# year_correct      1.000000

# %%
correlation_pairs = corr_matrix.unstack()
correlation_pairs
# Out:
# budget        budget          1.000000
#               gross           0.740028
#               runtime         0.318353
#               score           0.071552
#               votes           0.439077
#               year            0.326740
#               year_correct    0.319669
# gross         budget          0.740028
#               gross           1.000000
#               runtime         0.275641
#               score           0.222504
#               votes           0.614432
#               year            0.273512
#               year_correct    0.268141
# runtime       budget          0.318353
#               gross           0.275641
#               runtime         1.000000
#               score           0.414501
#               votes           0.352263
#               year            0.074849
#               year_correct    0.075183
# score         budget          0.071552
#               gross           0.222504
#               runtime         0.414501
#               score           1.000000
#               votes           0.474594
#               year            0.055681
#               year_correct    0.061443
# votes         budget          0.439077
#               gross           0.614432
#               runtime         0.352263
#               score           0.474594
#               votes           1.000000
#               year            0.204904
#               year_correct    0.202215
# year          budget          0.326740
#               gross           0.273512
#               runtime         0.074849
#               score           0.055681
#               votes           0.204904
#               year            1.000000
#               year_correct    0.998962
# year_correct  budget          0.319669
#               gross           0.268141
#               runtime         0.075183
#               score           0.061443
#               votes           0.202215
#               year            0.998962
#               year_correct    1.000000
# dtype: float64

# %%
sorted_pairs = correlation_pairs.sort_values()
sorted_pairs
# Out:
# score         year            0.055681
# year          score           0.055681
# score         year_correct    0.061443
# year_correct  score           0.061443
# score         budget          0.071552
# budget        score           0.071552
# year          runtime         0.074849
# runtime       year            0.074849
#               year_correct    0.075183
# year_correct  runtime         0.075183
# votes         year_correct    0.202215
# year_correct  votes           0.202215
# year          votes           0.204904
# votes         year            0.204904
# score         gross           0.222504
# gross         score           0.222504
#               year_correct    0.268141
# year_correct  gross           0.268141
# gross         year            0.273512
# year          gross           0.273512
# runtime       gross           0.275641
# gross         runtime         0.275641
# budget        runtime         0.318353
# runtime       budget          0.318353
# year_correct  budget          0.319669
# budget        year_correct    0.319669
#               year            0.326740
# year          budget          0.326740
# votes         runtime         0.352263
# runtime       votes           0.352263
#               score           0.414501
# score         runtime         0.414501
# budget        votes           0.439077
# votes         budget          0.439077
# score         votes           0.474594
# votes         score           0.474594
#               gross           0.614432
# gross         votes           0.614432
#               budget          0.740028
# budget        gross           0.740028
# year_correct  year            0.998962
# year          year_correct    0.998962
# budget        budget          1.000000
# score         score           1.000000
# votes         votes           1.000000
# runtime       runtime         1.000000
# gross         gross           1.000000
# year          year            1.000000
# year_correct  year_correct    1.000000
# dtype: float64

# %%
# Extracting high correlation and excluding the correlation of a column with itself as well as the year and extracted year columns
#high_correlation = sorted_pairs[sorted_pairs > 0.5]
high_correlation = sorted_pairs[sorted_pairs.between(left = 0.5, right = 0.99)]
high_correlation
# Out:
# votes   gross     0.614432
# gross   votes     0.614432
#         budget    0.740028
# budget  gross     0.740028
# dtype: float64

# %%
# Form the analysis that was conducted, we deduce that the gross profit have the highest correlation
# with the budget and the votes
